# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/mneha/OneDrive/Documents/GitHub/DSData/happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df['Happiness Score'].value_counts()
# Out:
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Standard Error'])
plt.xlabel(column,fontsize=20)
plt.tight_layout()

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Economy (GDP per Capita)'])
plt.xlabel(column,fontsize=20)
plt.tight_layout()

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
#we can see some skewness in standard error, family, health, trust and generosity

# %%
df =df.drop(columns=['Happiness Rank'])

# %%
df
# Out:
#          Country                           Region  Happiness Score  \
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 153       Rwanda               Sub-Saharan Africa            3.465
# 154        Benin               Sub-Saharan Africa            3.340
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
X= df.drop(columns=['Happiness Score'])
y= df['Happiness Score']

# %%
plt.figure(figsize=(6,4))
ax=sns.boxplot(df['Standard Error'])
plt.xlabel('Standard error', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(6,4))
ax=sns.boxplot(df['Economy (GDP per Capita)'])
plt.xlabel('GDP per capita', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(6,4))
ax=sns.boxplot(df['Family'])
plt.xlabel('Family', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(6,4))
ax=sns.boxplot(df['Health (Life Expectancy)'])
plt.xlabel('Health', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(6,4))
ax=sns.boxplot(df['Freedom'])
plt.xlabel('Freedom', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(6,4))
ax=sns.boxplot(df['Trust (Government Corruption)'])
plt.xlabel('Trust', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(6,4))
ax=sns.boxplot(df['Generosity'])
plt.xlabel('Generosity', fontsize=15)
plt.show()

# %%
#we can see the outliers in the same variables where we found skewness. As, our data is small we will treat the the skewness using cuberoot 
method rather than removing the data points with outliers.

# %%
df['Standard Error'] = np.cbrt(df['Standard Error'])

# %%
df['Family'] = np.cbrt(df['Family'])

# %%
df['Trust (Government Corruption)'] = np.cbrt(df['Trust (Government Corruption)'])

# %%
df['Generosity'] = np.cbrt(df['Generosity'])

# %%
df.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   0.979748
# Economy (GDP per Capita)        -0.317575
# Family                          -3.573056
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.011932
# Generosity                      -0.961079
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df.corr()
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.201754
# Standard Error                       -0.201754        1.000000
# Economy (GDP per Capita)              0.780966       -0.224064
# Family                                0.627187       -0.114105
# Health (Life Expectancy)              0.724200       -0.321062
# Freedom                               0.568211       -0.159027
# Trust (Government Corruption)         0.326229       -0.158530
# Generosity                            0.159029       -0.054081
# Dystopia Residual                     0.530474        0.063299
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.627187
# Standard Error                                -0.224064 -0.114105
# Economy (GDP per Capita)                       1.000000  0.565688
# Family                                         0.565688  1.000000
# ...

# %%
from scipy.stats import zscore

# %%
z_score = zscore(df[['Standard Error','Family','Generosity']])
abs_z_score = np.abs(z_score)

# %%
abs_z_score
# Out:
#      Standard Error    Family  Generosity
# 0          0.892612  0.952066    0.576890
# 1          0.172283  1.062927    1.325808
# 2          0.961125  0.975580    0.837993
# 3          0.524996  0.912350    0.869128
# 4          0.777930  0.894384    1.427657
# ..              ...       ...         ...
# 153        0.849442  0.507509    0.104570
# 154        0.696643  2.151835    0.239847
# 155        0.255966  1.583173    1.489900
# 156        2.157804  1.846619    0.118581
# 157        1.235787  3.619830    0.377864
#
# [158 rows x 3 columns]

# %%
np.where(abs_z_score >3)
# Out:
# (array([ 40,  63,  64, 101, 115, 147, 157], dtype=int64),
#  array([0, 2, 0, 2, 0, 1, 1], dtype=int64))

# %%
df1 = df[(abs_z_score<3).all(axis=1)]

df1.shape
# Out:
# (151, 11)

# %%
df.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   0.979748
# Economy (GDP per Capita)        -0.317575
# Family                          -3.573056
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.011932
# Generosity                      -0.961079
# Dystopia Residual               -0.238911
# dtype: float64

# %%
sns.lmplot(x='Standard Error', y='Happiness Score', data=df1)

# %%
sns.lmplot(x='Economy (GDP per Capita)', y='Happiness Score', data=df1)

# %%
sns.lmplot(x='Family', y='Happiness Score', data=df1)

# %%
sns.lmplot(x='Health (Life Expectancy)', y='Happiness Score', data=df1)

# %%
sns.lmplot(x='Freedom', y='Happiness Score', data=df1)

# %%
sns.lmplot(x='Trust (Government Corruption)', y='Happiness Score', data=df1)

# %%
sns.lmplot(x='Generosity', y='Happiness Score', data=df1)

# %%
sns.lmplot(x='Dystopia Residual', y='Happiness Score', data=df1)

# %%
# using a lmplot we can see a strong positive relation among the variable and target.

# %%
df1_corr = df1.corr()
plt.figure(figsize=(14,8))
sns.heatmap(df1_corr, annot=True, annot_kws={'size':10})
plt.show()

# %%
# we can see health and economy have a higher correlation of 0.81. It is a miltticollineraity issue.

# %%
X= df1.drop(columns=['Happiness Score'])
y= df1['Happiness Score']

# %%
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df1['Country'].unique
# Out:
# <bound method Series.unique of 0      Switzerland
# 1          Iceland
# 2          Denmark
# 3           Norway
# 4           Canada
#           ...
# 152    Afghanistan
# 153         Rwanda
# 154          Benin
# 155          Syria
# 156        Burundi
# Name: Country, Length: 151, dtype: object>

# %%
df1= df1.drop(0)
df1
# Out:
#          Country                           Region  Happiness Score  \
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# 5        Finland                   Western Europe            7.406
# ..           ...                              ...              ...
# 152  Afghanistan                    Southern Asia            3.575
# 153       Rwanda               Sub-Saharan Africa            3.465
# 154        Benin               Sub-Saharan Africa            3.340
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
#
#      Standard Error  Economy (GDP per Capita)    Family  \
# 1          0.365532                   1.30232  1.119283
# ...

# %%
df1
# Out:
#          Country                           Region  Happiness Score  \
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# 5        Finland                   Western Europe            7.406
# ..           ...                              ...              ...
# 152  Afghanistan                    Southern Asia            3.575
# 153       Rwanda               Sub-Saharan Africa            3.465
# 154        Benin               Sub-Saharan Africa            3.340
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
#
#      Standard Error  Economy (GDP per Capita)    Family  \
# 1          0.365532                   1.30232  1.119283
# ...

# %%
X= df1.drop(columns=['Happiness Score'])
y= df1['Happiness Score']

# %%
Scaler = StandardScaler()
X_scaled = Scaler.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37344\2148882468.py in <module>
#       1 Scaler = StandardScaler()
# ----> 2 X_scaled = Scaler.fit_transform(X)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
# ...

# %%
df1 = df1.drop(columns = ['Country'])
df1
# Out:
#                               Region  Happiness Score  Standard Error  \
# 1                     Western Europe            7.561        0.365532
# 2                     Western Europe            7.527        0.321658
# 3                     Western Europe            7.522        0.338540
# 4                      North America            7.427        0.328749
# 5                     Western Europe            7.406        0.315483
# ..                               ...              ...             ...
# 152                    Southern Asia            3.575        0.313597
# 153               Sub-Saharan Africa            3.465        0.325981
# 154               Sub-Saharan Africa            3.340        0.331896
# 155  Middle East and Northern Africa            3.006        0.368771
# 156               Sub-Saharan Africa            2.905        0.442391
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df1 = df1.drop(columns = ['Region'])
df1
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)    Family  \
# 1              7.561        0.365532                   1.30232  1.119283
# 2              7.527        0.321658                   1.32548  1.108089
# 3              7.522        0.338540                   1.45900  1.099986
# 4              7.427        0.328749                   1.32629  1.097684
# 5              7.406        0.315483                   1.29025  1.096479
# ..               ...             ...                       ...       ...
# 152            3.575        0.313597                   0.31982  0.671546
# 153            3.465        0.325981                   0.22208  0.918031
# 154            3.340        0.331896                   0.28665  0.707311
# 155            3.006        0.368771                   0.66320  0.780185
# 156            2.905        0.442391                   0.01530  0.746424
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
X= df1.drop(columns=['Happiness Score'])
y= df1['Happiness Score']

# %%
Scaler = StandardScaler()
X_scaled = Scaler.fit_transform(X)

# %%
vif = pd.DataFrame()
vif["vif"]=[variance_inflation_factor(X_scaled,i)for i in range(len(X.columns))]
vif["Features"]= X.columns
vif
# Out:
#         vif                       Features
# 0  1.155348                 Standard Error
# 1  3.896585       Economy (GDP per Capita)
# 2  1.821309                         Family
# 3  3.317035       Health (Life Expectancy)
# 4  1.838387                        Freedom
# 5  1.345422  Trust (Government Corruption)
# 6  1.265589                     Generosity
# 7  1.041556              Dystopia Residual

# %%
# all the vif values are less than 5 so no issue of multicollinearity can be seen.

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor , RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN

# %%
maxAccu=0
maxRS=0
for i in range(1,300):
    x_train,x_test,y_train,y_test= train_test_split(X,y,test_size=0.20, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is", maxAccu,"on random_state ", maxRS)
# Out:
# Maximum r2 score is 0.998857786889566 on random_state  73

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=maxRS)

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2_score ", r2_score(y_test, predLR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predLR))
print("Mean squared error ", mean_squared_error(y_test,predLR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predLR)))
# Out:
# R2_score  0.998857786889566
# R2_score on training data  99.69550303429155
# Mean Absolute Error  0.03230878460409373
# Mean squared error  0.0016615422265081907
# Root mean squared error  0.0407620194115575

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test, predLR)
plt.plot(predLR, predLR)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual v/s predicted model')
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
predRFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2_score ", r2_score(y_test, predRFR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predRFR))
print("Mean squared error ", mean_squared_error(y_test,predRFR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predRFR)))
# Out:
# R2_score  0.8764091192627899
# R2_score on training data  98.48298563685759
# Mean Absolute Error  0.32763266666666674
# Mean squared error  0.17978384706000003
# Root mean squared error  0.4240092535075149

# %%
knn=KNN()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2_score ", r2_score(y_test, predknn))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predknn))
print("Mean squared error ", mean_squared_error(y_test,predknn))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predknn)))
# Out:
# R2_score  0.9425649321129044
# R2_score on training data  95.33285355121438
# Mean Absolute Error  0.2174000000000001
# Mean squared error  0.0835490240000001
# Root mean squared error  0.28904848036272407

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
predGBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2_score ", r2_score(y_test, predGBR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predGBR))
print("Mean squared error ", mean_squared_error(y_test,predGBR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predGBR)))
# Out:
# R2_score  0.9179376649991225
# R2_score on training data  99.93717761173892
# Mean Absolute Error  0.2664329961361241
# Mean squared error  0.1193735508411369
# Root mean squared error  0.3455047768716619

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
predlasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2_score ", r2_score(y_test, predlasso))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predlasso))
print("Mean squared error ", mean_squared_error(y_test,predlasso))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predlasso)))
# Out:
# R2_score  -0.00019460137457039117
# R2_score on training data  0.0
# Mean Absolute Error  1.0310544444444443
# Mean squared error  1.4549522761805558
# Root mean squared error  1.2062140258596548

# %%
ridge=Ridge()
ridge.fit(x_train,y_train)
predridge=ridge.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2_score ", r2_score(y_test, predridge))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predridge))
print("Mean squared error ", mean_squared_error(y_test,predridge))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predridge)))
# Out:
# R2_score  0.9892335533393679
# R2_score on training data  98.48298563685759
# Mean Absolute Error  0.10207448560429364
# Mean squared error  0.015661618302813502
# Root mean squared error  0.12514638749406035

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
predDTR=DTR.predict(x_test)
pred_train=DTR.predict(x_train)
print("R2_score ", r2_score(y_test, predDTR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predDTR))
print("Mean squared error ", mean_squared_error(y_test,predDTR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predDTR)))
# Out:
# R2_score  0.8224517293766147
# R2_score on training data  100.0
# Mean Absolute Error  0.4292666666666668
# Mean squared error  0.258274
# Root mean squared error  0.5082066508813122

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
predsvr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2_score ", r2_score(y_test, predsvr))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predsvr))
print("Mean squared error ", mean_squared_error(y_test,predsvr))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predsvr)))
# Out:
# R2_score  0.9705282785858029
# R2_score on training data  98.8601477025052
# Mean Absolute Error  0.11627231539376642
# Mean squared error  0.042871605281227486
# Root mean squared error  0.20705459492903674

# %%
from sklearn.ensemble import ExtraTreesRegressor
ETR=ExtraTreesRegressor()
ETR.fit(x_train,y_train)
predETR=ETR.predict(x_test)
pred_train=ETR.predict(x_train)
print("R2_score ", r2_score(y_test, predETR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predETR))
print("Mean squared error ", mean_squared_error(y_test,predETR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predETR)))
# Out:
# R2_score  0.9053144387025184
# R2_score on training data  100.0
# Mean Absolute Error  0.2793563333333339
# Mean squared error  0.1377361692833338
# Root mean squared error  0.37112823832650327

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(LR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predLR)-score.mean())*100)
# Out:
# [0.93317675 0.91703674 0.9034381  0.90231022 0.94184911]
# 0.9195621827938257
# The difference between R2 score and CV score is  7.929560409574021

# %%
score = cross_val_score(RFR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predRFR)-score.mean())*100)
# Out:
# [-7.63690591 -1.79591189 -1.13074523 -2.25282056 -6.10919567]
# -3.7851158550679265
# The difference between R2 score and CV score is  466.15249743307163

# %%
score = cross_val_score(knn,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predknn)-score.mean())*100)
# Out:
# [-7.18948956 -2.99661789 -1.58323859 -3.35821569 -5.4382048 ]
# -4.113153306743423
# The difference between R2 score and CV score is  505.57182388563274

# %%
score = cross_val_score(GBR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predGBR)-score.mean())*100)
# Out:
# [-3.61361735 -1.07322497 -1.24767532 -2.02297859 -3.91390503]
# -2.3742802500635944
# The difference between R2 score and CV score is  329.2217915062717

# %%
score = cross_val_score(lasso,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predlasso)-score.mean())*100)
# Out:
# [-43.83167078 -12.55137464  -0.28995202 -28.41091069 -26.09403887]
# -22.235589400147756
# The difference between R2 score and CV score is  2223.5394798773186

# %%
score = cross_val_score(ridge,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predridge)-score.mean())*100)
# Out:
# [-0.08461681  0.74535497  0.62645887  0.20005165  0.70821827]
# 0.43909339069755876
# The difference between R2 score and CV score is  55.014016264180924

# %%
score = cross_val_score(DTR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predDTR)-score.mean())*100)
# Out:
# [ -6.07943568  -7.59164175  -6.74276857 -12.15423151  -6.76164676]
# -7.865944852941721
# The difference between R2 score and CV score is  868.8396582318335

# %%
score = cross_val_score(svr,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predsvr)-score.mean())*100)
# Out:
# [-1.48955538  0.7712574   0.58180257  0.57588897 -1.56115906]
# -0.22435310080847842
# The difference between R2 score and CV score is  119.48813793942814

# %%
score = cross_val_score(ETR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predETR)-score.mean())*100)
# Out:
# [-7.36960192 -0.44311579 -0.69551582 -1.128413   -5.24737724]
# -2.976804753076719
# The difference between R2 score and CV score is  388.2119191779238

# %%
from sklearn.model_selection import GridSearchCV

# %%
Final_model = LinearRegression()
Final_model.fit(x_train, y_train)
pred=Final_model.predict(x_test)
pred_train=Final_model.predict(x_train)
print("R2_score ", r2_score(y_test, pred))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, pred))
print("Mean squared error ", mean_squared_error(y_test,pred))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# R2_score  0.998857786889566
# R2_score on training data  99.69550303429155
# Mean Absolute Error  0.03230878460409373
# Mean squared error  0.0016615422265081907
# Root mean squared error  0.0407620194115575

# %%
import pickle
filename = 'Happiness_score_prediction.pkl'
pickle.dump(Final_model, open(filename, 'wb'))

# %%
loaded_model= pickle.load(open('Happiness_score_prediction.pkl', 'rb'))
result = loaded_model.score(x_test, y_test)
print(result*100)
# Out:
# 99.88577868895659
