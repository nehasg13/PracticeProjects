# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("C:/Users/mneha/OneDrive/Documents/GitHub/DSData/dataset1-master/dataset1-master/titanic_train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Survived'].replace({0:'Died', 1:'Survived'}, inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1      Died       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              5      Died       3
# ..           ...       ...     ...
# 886          887      Died       2
# 887          888  Survived       1
# 888          889      Died       3
# 889          890  Survived       1
# 890          891      Died       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
survived_cnt = pd.crosstab(df["Survived"], df["Sex"],margins=True)
survived_cnt
# Out:
# Sex       female  male  All
# Survived
# Died          81   468  549
# Survived     233   109  342
# All          314   577  891

# %%
class_gen_cnt = pd.crosstab(df["Survived"],df["Pclass"], margins=True)
class_gen_cnt
# Out:
# Pclass      1    2    3  All
# Survived
# Died       80   97  372  549
# Survived  136   87  119  342
# All       216  184  491  891

# %%
gen_pclass_cnt = pd.crosstab(df["Sex"],df["Pclass"], margins=True)
gen_pclass_cnt
# Out:
# Pclass    1    2    3  All
# Sex
# female   94   76  144  314
# male    122  108  347  577
# All     216  184  491  891

# %%
#from the above we can state that male passengers died more than females. and the passengers of first class survived the most 
and the passengers of third class died the most.

# %%
age_missing = df[df['Age'].isna()]
age_missing
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6      Died       3                          Moran, Mr. James
# 17            18  Survived       2              Williams, Mr. Charles Eugene
# 19            20  Survived       3                   Masselmani, Mrs. Fatima
# 26            27      Died       3                   Emir, Mr. Farred Chehab
# 28            29  Survived       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860      Died       3                          Razi, Mr. Raihed
# 863          864      Died       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869      Died       3               van Melkebeke, Mr. Philemon
# 878          879      Died       3                        Laleff, Mr. Kristo
# 888          889      Died       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1      Died       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              5      Died       3
# ..           ...       ...     ...
# 886          887      Died       2
# 887          888  Survived       1
# 888          889      Died       3
# 889          890  Survived       1
# 890          891      Died       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1      Died       3
# 1            2  Survived       1
# 2            3  Survived       3
# 3            4  Survived       1
# 4            5      Died       3
# 5            6      Died       3
# 6            7      Died       1
# 7            8      Died       3
# 8            9  Survived       3
# 9           10  Survived       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Cabin'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
fig, axes = plt.subplots(2, 4, figsize=(16, 10))
sns.countplot('Survived',data=df,ax=axes[0,0])
sns.countplot('Pclass',data=df,ax=axes[0,1])
sns.countplot('Sex',data=df,ax=axes[0,2])
sns.countplot('SibSp',data=df,ax=axes[0,3])
sns.countplot('Parch',data=df,ax=axes[1,0])
sns.countplot('Embarked',data=df,ax=axes[1,1])
sns.distplot(df['Fare'], kde=True,ax=axes[1,2])
sns.distplot(df['Age'],kde=True,ax=axes[1,3])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
df= df.set_index('PassengerId')
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                Died       3
# 2            Survived       1
# 3            Survived       3
# 4            Survived       1
# 5                Died       3
# ...               ...     ...
# 887              Died       2
# 888          Survived       1
# 889              Died       3
# 890          Survived       1
# 891              Died       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
corr= df.corr()
plt.figure(figsize=(14,8))
sns.heatmap(corr, annot=True, annot_kws={'size':10})
plt.show()

# %%
# as we can see 687 values of cabin column is missing. we will drop that entire column.

# %%
df = df.drop(columns ='Cabin', axis=1)
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                Died       3
# 2            Survived       1
# 3            Survived       3
# 4            Survived       1
# 5                Died       3
# ...               ...     ...
# 887              Died       2
# 888          Survived       1
# 889              Died       3
# 890          Survived       1
# 891              Died       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
df.dropna( inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                Died       3
# 2            Survived       1
# 3            Survived       3
# 4            Survived       1
# 5                Died       3
# ...               ...     ...
# 887              Died       2
# 888          Survived       1
# 889              Died       3
# 890          Survived       1
# 891              Died       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
df = df.drop(columns ='Name', axis=1)
df
# Out:
#              Survived  Pclass     Sex        Age  SibSp  Parch  \
# PassengerId
# 1                Died       3    male  22.000000      1      0
# 2            Survived       1  female  38.000000      1      0
# 3            Survived       3  female  26.000000      0      0
# 4            Survived       1  female  35.000000      1      0
# 5                Died       3    male  35.000000      0      0
# ...               ...     ...     ...        ...    ...    ...
# 887              Died       2    male  27.000000      0      0
# 888          Survived       1  female  19.000000      0      0
# 889              Died       3  female  29.699118      1      2
# 890          Survived       1    male  26.000000      0      0
# 891              Died       3    male  32.000000      0      0
#
#                        Ticket     Fare Embarked
# PassengerId
# 1                   A/5 21171   7.2500        S
# 2                    PC 17599  71.2833        C
# ...

# %%
df = df.drop(columns ='Ticket', axis=1)
df
# Out:
#              Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# PassengerId
# 1                Died       3    male  22.000000      1      0   7.2500
# 2            Survived       1  female  38.000000      1      0  71.2833
# 3            Survived       3  female  26.000000      0      0   7.9250
# 4            Survived       1  female  35.000000      1      0  53.1000
# 5                Died       3    male  35.000000      0      0   8.0500
# ...               ...     ...     ...        ...    ...    ...      ...
# 887              Died       2    male  27.000000      0      0  13.0000
# 888          Survived       1  female  19.000000      0      0  30.0000
# 889              Died       3  female  29.699118      1      2  23.4500
# 890          Survived       1    male  26.000000      0      0  30.0000
# 891              Died       3    male  32.000000      0      0   7.7500
#
#             Embarked
# PassengerId
# 1                  S
# 2                  C
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 1 to 891
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  889 non-null    object
#  1   Pclass    889 non-null    int64
#  2   Sex       889 non-null    object
#  3   Age       889 non-null    float64
#  4   SibSp     889 non-null    int64
#  5   Parch     889 non-null    int64
#  6   Fare      889 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 62.5+ KB

# %%
df['Sex'].replace({'male':0,'female':1},inplace=True)
df.head()
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                Died       3    0  22.0      1      0   7.2500        S
# 2            Survived       1    1  38.0      1      0  71.2833        C
# 3            Survived       3    1  26.0      0      0   7.9250        S
# 4            Survived       1    1  35.0      1      0  53.1000        S
# 5                Died       3    0  35.0      0      0   8.0500        S

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()

# %%
df1 = lab_enc.fit_transform(df['Embarked'])

# %%
df['Embarked']=df1
df
# Out:
#              Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# PassengerId
# 1                Died       3    0  22.000000      1      0   7.2500         2
# 2            Survived       1    1  38.000000      1      0  71.2833         0
# 3            Survived       3    1  26.000000      0      0   7.9250         2
# 4            Survived       1    1  35.000000      1      0  53.1000         2
# 5                Died       3    0  35.000000      0      0   8.0500         2
# ...               ...     ...  ...        ...    ...    ...      ...       ...
# 887              Died       2    0  27.000000      0      0  13.0000         2
# 888          Survived       1    1  19.000000      0      0  30.0000         2
# 889              Died       3    1  29.699118      1      2  23.4500         2
# 890          Survived       1    0  26.000000      0      0  30.0000         0
# 891              Died       3    0  32.000000      0      0   7.7500         1
#
# ...

# %%
#as Name and Ticket variable would not have contributed much to the analysis, so we deleted the column and encoded Embarked.

# %%
X=df.drop('Survived',axis=1)
y=df['Survived']

# %%
Scaler=StandardScaler()
X=pd.DataFrame(Scaler.fit_transform(X),columns=X.columns)
X
# Out:
#        Pclass       Sex       Age     SibSp     Parch      Fare  Embarked
# 0    0.825209 -0.735342 -0.590495  0.431350 -0.474326 -0.500240  0.586840
# 1   -1.572211  1.359911  0.643971  0.431350 -0.474326  0.788947 -1.939555
# 2    0.825209  1.359911 -0.281878 -0.475199 -0.474326 -0.486650  0.586840
# 3   -1.572211  1.359911  0.412509  0.431350 -0.474326  0.422861  0.586840
# 4    0.825209 -0.735342  0.412509 -0.475199 -0.474326 -0.484133  0.586840
# ..        ...       ...       ...       ...       ...       ...       ...
# 884 -0.373501 -0.735342 -0.204724 -0.475199 -0.474326 -0.384475  0.586840
# 885 -1.572211  1.359911 -0.821957 -0.475199 -0.474326 -0.042213  0.586840
# 886  0.825209  1.359911  0.003524  0.431350  2.006119 -0.174084  0.586840
# 887 -1.572211 -0.735342 -0.281878 -0.475199 -0.474326 -0.042213 -1.939555
# 888  0.825209 -0.735342  0.181046 -0.475199 -0.474326 -0.490173 -0.676357
#
# [889 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve
from sklearn.model_selection import cross_val_score

# %%
maxAccu=0
maxRS=0
for i in range(1,300):
    x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=i)
    LR = LogisticRegression()
    LR.fit(x_train,y_train)
    pred = LR.predict(x_test)
    accu = accuracy_score(pred, y_test)
    if accu>maxAccu:
        maxAccu=accu
        maxRS=i
print("Best accuracy is ", accu,"at random state ", maxRS)
# Out:
# Best accuracy is  0.8089887640449438 at random state  24

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=maxRS)

# %%
LR = LogisticRegression()
LR.fit(x_train,y_train)
predLR = LR.predict(x_test)
print(accuracy_score(y_test, predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.8820224719101124
# [[110   6]
#  [ 15  47]]
#               precision    recall  f1-score   support
#
#         Died       0.88      0.95      0.91       116
#     Survived       0.89      0.76      0.82        62
#
#     accuracy                           0.88       178
#    macro avg       0.88      0.85      0.87       178
# weighted avg       0.88      0.88      0.88       178

# %%
RFC = RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test, predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.8595505617977528
# [[104  12]
#  [ 13  49]]
#               precision    recall  f1-score   support
#
#         Died       0.89      0.90      0.89       116
#     Survived       0.80      0.79      0.80        62
#
#     accuracy                           0.86       178
#    macro avg       0.85      0.84      0.84       178
# weighted avg       0.86      0.86      0.86       178

# %%
GB = GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB = GB.predict(x_test)
print(accuracy_score(y_test, predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.8764044943820225
# [[110   6]
#  [ 16  46]]
#               precision    recall  f1-score   support
#
#         Died       0.87      0.95      0.91       116
#     Survived       0.88      0.74      0.81        62
#
#     accuracy                           0.88       178
#    macro avg       0.88      0.85      0.86       178
# weighted avg       0.88      0.88      0.87       178

# %%
ABC = AdaBoostClassifier()
ABC.fit(x_train,y_train)
predABC = ABC.predict(x_test)
print(accuracy_score(y_test, predABC))
print(confusion_matrix(y_test,predABC))
print(classification_report(y_test,predABC))
# Out:
# 0.8539325842696629
# [[104  12]
#  [ 14  48]]
#               precision    recall  f1-score   support
#
#         Died       0.88      0.90      0.89       116
#     Survived       0.80      0.77      0.79        62
#
#     accuracy                           0.85       178
#    macro avg       0.84      0.84      0.84       178
# weighted avg       0.85      0.85      0.85       178

# %%
ET = ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET = ET.predict(x_test)
print(accuracy_score(y_test, predET))
print(confusion_matrix(y_test,predET))
print(classification_report(y_test,predET))
# Out:
# 0.8146067415730337
# [[98 18]
#  [15 47]]
#               precision    recall  f1-score   support
#
#         Died       0.87      0.84      0.86       116
#     Survived       0.72      0.76      0.74        62
#
#     accuracy                           0.81       178
#    macro avg       0.80      0.80      0.80       178
# weighted avg       0.82      0.81      0.82       178

# %%
from sklearn.svm import SVC

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
svc = SVC()
svc.fit(x_train,y_train)
predsvc = svc.predict(x_test)
print(accuracy_score(y_test, predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.8651685393258427
# [[110   6]
#  [ 18  44]]
#               precision    recall  f1-score   support
#
#         Died       0.86      0.95      0.90       116
#     Survived       0.88      0.71      0.79        62
#
#     accuracy                           0.87       178
#    macro avg       0.87      0.83      0.84       178
# weighted avg       0.87      0.87      0.86       178

# %%
KNN = KNeighborsClassifier()
KNN.fit(x_train,y_train)
predKNN = LR.predict(x_test)
print(accuracy_score(y_test, predKNN))
print(confusion_matrix(y_test,predKNN))
print(classification_report(y_test,predKNN))
# Out:
# 0.8820224719101124
# [[110   6]
#  [ 15  47]]
#               precision    recall  f1-score   support
#
#         Died       0.88      0.95      0.91       116
#     Survived       0.89      0.76      0.82        62
#
#     accuracy                           0.88       178
#    macro avg       0.88      0.85      0.87       178
# weighted avg       0.88      0.88      0.88       178

# %%
score = cross_val_score(LR,X,y)
print(score)
print(score.mean())
print("The difference between Accuracy score and CV score is ", accuracy_score(y_test, predLR)-score.mean())
# Out:
# [0.7752809  0.78651685 0.78089888 0.76404494 0.81920904]
# 0.7851901225163461
# The difference between Accuracy score and CV score is  0.09683234939376628

# %%
score = cross_val_score(RFC, X, y)
print(score)
print(score.mean())
print("The difference between Accuracy score and CV score is ", accuracy_score(y_test, predRFC)-score.mean())
# Out:
# [0.78651685 0.80898876 0.86516854 0.78651685 0.83615819]
# 0.8166698406652702
# The difference between Accuracy score and CV score is  0.042880721132482646

# %%
score = cross_val_score(GB, X, y)
print(score)
print(score.mean())
print("The difference between Accuracy score and CV score is ", accuracy_score(y_test, predGB)-score.mean())
# Out:
# [0.80337079 0.83146067 0.84269663 0.79775281 0.85310734]
# 0.8256776487018346
# The difference between Accuracy score and CV score is  0.050726845680187926

# %%
score = cross_val_score(ABC, X, y)
print(score)
print(score.mean())
print("The difference between Accuracy score and CV score is ", accuracy_score(y_test, predABC)-score.mean())
# Out:
# [0.75842697 0.81460674 0.80898876 0.78651685 0.82485876]
# 0.7986796165809686
# The difference between Accuracy score and CV score is  0.055252967688694254

# %%
score = cross_val_score(ET, X, y)
print(score)
print(score.mean())
print("The difference between Accuracy score and CV score is ", accuracy_score(y_test, predET)-score.mean())
# Out:
# [0.76966292 0.76966292 0.84269663 0.78089888 0.83050847]
# 0.7986859645781756
# The difference between Accuracy score and CV score is  0.015920776994858055

# %%
score = cross_val_score(svc, X, y)
print(score)
print(score.mean())
print("The difference between Accuracy score and CV score is ", accuracy_score(y_test, predsvc)-score.mean())
# Out:
# [0.83146067 0.82022472 0.81460674 0.80337079 0.86440678]
# 0.8268139402018664
# The difference between Accuracy score and CV score is  0.03835459912397632

# %%
score = cross_val_score(KNN, X, y)
print(score)
print(score.mean())
print("The difference between Accuracy score and CV score is ", accuracy_score(y_test, predKNN)-score.mean())
# Out:
# [0.78089888 0.76966292 0.82022472 0.81460674 0.82485876]
# 0.8020504030978227
# The difference between Accuracy score and CV score is  0.07997206881228969

# %%
params = {'C':[1,5,10,20], 
         'gamma':[0.001, 0.01, 0.02, 0.002]}

# %%
gridsearch= GridSearchCV(svc, params)
gridsearch.fit(x_train, y_train)
gridsearch.best_params_
# Out:
# {'C': 20, 'gamma': 0.02}

# %%
gridsearch.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20],
#                          'gamma': [0.001, 0.01, 0.02, 0.002]})

# %%
gridsearch.best_params_
# Out:
# {'C': 20, 'gamma': 0.02}

# %%
Final_model = SVC(C=20, gamma=0.02)
Final_model.fit(x_train,y_train)
pred= Final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 88.76404494382022

# %%
import pickle
filename = 'Titanic_dataset.pkl'
pickle.dump(Final_model, open(filename, 'wb'))

# %%
loaded_model= pickle.load(open('Titanic_dataset.pkl', 'rb'))
result = loaded_model.score(x_test, y_test)
print(result*100)
# Out:
# 88.76404494382022
