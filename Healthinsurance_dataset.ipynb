# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:/Users/mneha/OneDrive/Documents/GitHub/DSData/SBI_Life_insurance.csv")
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# bmi         float64
# children      int64
# smoker        int64
# region        int64
# charges     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   region    1338 non-null   int64
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(5)
# memory usage: 73.3 KB

# %%
df.age.nunique()
# Out:
# 47

# %%
df.age.value_counts()
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
df.sex.nunique()
# Out:
# 2

# %%
df.sex.value_counts()
# Out:
# 1    676
# 0    662
# Name: sex, dtype: int64

# %%
df.bmi.nunique()
# Out:
# 548

# %%
df.children.nunique()
# Out:
# 6

# %%
df.children.value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df.smoker.nunique()
# Out:
# 2

# %%
df.region.nunique()
# Out:
# 4

# %%
df.region.value_counts()
# Out:
# 2    364
# 3    325
# 1    325
# 0    324
# Name: region, dtype: int64

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.515695  13270.422265
# std       1.104885  12110.011237
# min       0.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       2.000000   9382.033000
# 75%       2.000000  16639.912515
# max       3.000000  63770.428010

# %%
plt.figure(figsize=(25,20), facecolor="white")
plotnumber=1
for columns in df:
    if plotnumber<=7:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(df[columns])
        plt.xlabel(columns, fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
sns.lmplot(x='age',y='charges',data=df,palette="colourblind")

# %%
sns.lmplot(x='bmi',y='charges',data=df,palette="colourblind")

# %%
sns.countplot(x='smoker', data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.pairplot(data=df, palette='Dark2')

# %%
sns.lmplot(x='age',y='bmi',data=df,palette='colourblind')

# %%
plt.figure(figsize=(25,20))
plotnumber=1
for i in df:
    if plotnumber<=7:
        ax=plt.subplot(2,4,plotnumber)
        sns.regplot(x='charges',y=i,data=df, color='r')
        plt.xlabel('charges')
        plt.ylabel(i)
    plotnumber+=1
plt.show()

# %%
sns.lmplot(x='smoker',y='bmi',data=df,palette="colourblind")

# %%
#we can see a linear relationship between age and charges, bmi and charges, age and bmi, and smoker and charges.

# %%
plt.figure(figsize=(25,20))
p=1
for columns in df:
    if p<=7:
        ax=plt.subplot(2,4,p)
        sns.boxplot(df[columns])
        plt.xlabel(columns,fontsize=13)
    p+=1

plt.show()

# %%
#we can see outliers in bmi

# %%
from scipy.stats import zscore

# %%
z_score= zscore(df['bmi'])
abs_z_score= np.abs(z_score)
abs_z_score
# Out:
# 0       0.453320
# 1       0.509621
# 2       0.383307
# 3       1.305531
# 4       0.292556
#           ...
# 1333    0.050297
# 1334    0.206139
# 1335    1.014878
# 1336    0.797813
# 1337    0.261388
# Name: bmi, Length: 1338, dtype: float64

# %%
np.where(abs_z_score>3)
# Out:
# (array([ 116,  847, 1047, 1317], dtype=int64),)

# %%
filtering_entry=(abs_z_score<3)
df=df[filtering_entry]
df.shape
# Out:
# (1334, 7)

# %%
df.skew()
# Out:
# age         0.053603
# sex        -0.015010
# bmi         0.205622
# children    0.935415
# smoker      1.465804
# region     -0.034385
# charges     1.517663
# dtype: float64

# %%
z1_score= zscore(df['charges'])
abs_z1_score= np.abs(z1_score)
abs_z1_score
# Out:
# 0       0.299484
# 1       0.954898
# 2       0.729505
# 3       0.721452
# 4       0.777713
#           ...
# 1333    0.220525
# 1334    0.915144
# 1335    0.962818
# 1336    0.931531
# 1337    1.313658
# Name: charges, Length: 1334, dtype: float64

# %%
np.where(abs_z1_score>3)
# Out:
# (array([  34,  542,  576,  818, 1143, 1227, 1238, 1297], dtype=int64),)

# %%
filtering_entry=(abs_z1_score<3)
df=df[filtering_entry]
df.shape
# Out:
# (1326, 7)

# %%
df.skew()
# Out:
# age         0.055041
# sex        -0.012080
# bmi         0.205412
# children    0.934995
# smoker      1.502879
# region     -0.032434
# charges     1.452829
# dtype: float64

# %%
df['charges']=np.cbrt(df['charges'])

# %%
df.skew()
# Out:
# age         0.055041
# sex        -0.012080
# bmi         0.205412
# children    0.934995
# smoker      1.502879
# region     -0.032434
# charges     0.489123
# dtype: float64

# %%
df.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.021967  0.116759  0.042138 -0.029898  0.000787  0.455965
# sex      -0.021967  1.000000  0.038771  0.017007  0.074308 -0.000070  0.025532
# bmi       0.116759  0.038771  1.000000  0.019666 -0.009599  0.156190  0.150034
# children  0.042138  0.017007  0.019666  1.000000  0.009407  0.018826  0.129176
# smoker   -0.029898  0.074308 -0.009599  0.009407  1.000000 -0.004939  0.724594
# region    0.000787 -0.000070  0.156190  0.018826 -0.004939  1.000000 -0.033271
# charges   0.455965  0.025532  0.150034  0.129176  0.724594 -0.033271  1.000000

# %%
df_corr=df.corr()
plt.figure(figsize=(14,8))
sns.heatmap(df_corr,annot=True,annot_kws={'size':10})
plt.show()

# %%
#from the heatmap we can the strong relation between age and charges, smoker and chrges, and bmi and charges.

# %%
X= df.drop(columns=['charges'])
y=df['charges']

# %%
X.shape
# Out:
# (1326, 6)

# %%
y.shape
# Out:
# (1326,)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
Scaler=StandardScaler()
X_scaled = Scaler.fit_transform(X)
X_scaled
# Out:
# array([[-1.4397224 , -1.00605149, -0.44521866, -0.90985003,  2.00094317,
#          1.34412035],
#        [-1.51101761,  0.99398491,  0.53508645, -0.08123661, -0.49976432,
#          0.44031529],
#        [-0.79806549,  0.99398491,  0.40649447,  1.57599023, -0.49976432,
#          0.44031529],
#        ...,
#        [-1.51101761, -1.00605149,  1.04945437, -0.90985003, -0.49976432,
#          0.44031529],
#        [-1.29713198, -1.00605149, -0.79592406, -0.90985003, -0.49976432,
#          1.34412035],
#        [ 1.55467652, -1.00605149, -0.24982565, -0.90985003,  2.00094317,
#         -0.46348977]])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif["vif"]=[variance_inflation_factor(X_scaled,i) for i in range(len(X.columns))]
vif["Features"]=X.columns
vif
# Out:
#         vif  Features
# 0  1.017339       age
# 1  1.008065       sex
# 2  1.041564       bmi
# 3  1.002677  children
# 4  1.006552    smoker
# 5  1.025679    region

# %%
#all the vif values are less than 5 and are very low. That means no multicollinearity.

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor , RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN

# %%
maxAccu=0
maxRS=0
for i in range(1,300):
    x_train,x_test,y_train,y_test= train_test_split(X,y,test_size=0.20, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is", maxAccu,"on random_state ", maxRS)
# Out:
# Maximum r2 score is 0.8528294873066411 on random_state  217

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=maxRS)

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2_score ", r2_score(y_test, predLR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predLR))
print("Mean squared error ", mean_squared_error(y_test,predLR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predLR)))
# Out:
# R2_score  0.8528294873066411
# R2_score on training data  75.5000848179447
# Mean Absolute Error  1.7801110010427397
# Mean squared error  6.7781789718424825
# Root mean squared error  2.6034936089498055

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test, predLR)
plt.plot(predLR, predLR)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual v/s predicted model')
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
predRFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2_score ", r2_score(y_test, predRFR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predRFR))
print("Mean squared error ", mean_squared_error(y_test,predRFR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predRFR)))
# Out:
# R2_score  0.8944473909679287
# R2_score on training data  96.63287747812177
# Mean Absolute Error  1.23325934622125
# Mean squared error  4.861398264304487
# Root mean squared error  2.2048578784820774

# %%
knn=KNN()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2_score ", r2_score(y_test, predknn))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predknn))
print("Mean squared error ", mean_squared_error(y_test,predknn))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predknn)))
# Out:
# R2_score  0.24246421370800864
# R2_score on training data  47.23186033226779
# Mean Absolute Error  4.304929740663078
# Mean squared error  34.88955119536144
# Root mean squared error  5.906737779465197

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
predGBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2_score ", r2_score(y_test, predGBR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predGBR))
print("Mean squared error ", mean_squared_error(y_test,predGBR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predGBR)))
# Out:
# R2_score  0.9096895181484017
# R2_score on training data  86.06937171781706
# Mean Absolute Error  1.2071988319824376
# Mean squared error  4.159397136156668
# Root mean squared error  2.0394600109236434

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
predlasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2_score ", r2_score(y_test, predlasso))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predlasso))
print("Mean squared error ", mean_squared_error(y_test,predlasso))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predlasso)))
# Out:
# R2_score  0.6638968365133395
# R2_score on training data  58.418916536056486
# Mean Absolute Error  3.1103330935515485
# Mean squared error  15.479781604496784
# Root mean squared error  3.9344353603149695

# %%
ridge=Ridge()
ridge.fit(x_train,y_train)
predridge=ridge.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2_score ", r2_score(y_test, predridge))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predridge))
print("Mean squared error ", mean_squared_error(y_test,predridge))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predridge)))
# Out:
# R2_score  0.852594156430766
# R2_score on training data  96.63287747812177
# Mean Absolute Error  1.786358154093665
# Mean squared error  6.7890175207140615
# Root mean squared error  2.605574316866449

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
predDTR=DTR.predict(x_test)
pred_train=DTR.predict(x_train)
print("R2_score ", r2_score(y_test, predDTR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predDTR))
print("Mean squared error ", mean_squared_error(y_test,predDTR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predDTR)))
# Out:
# R2_score  0.7555111922225536
# R2_score on training data  99.57410888469308
# Mean Absolute Error  1.4918027111926988
# Mean squared error  11.260332422574395
# Root mean squared error  3.3556418793688927

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
predsvr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2_score ", r2_score(y_test, predsvr))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predsvr))
print("Mean squared error ", mean_squared_error(y_test,predsvr))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predsvr)))
# Out:
# R2_score  0.11385923169566015
# R2_score on training data  -0.30141877786873383
# Mean Absolute Error  3.436406008006653
# Mean squared error  40.81266424835835
# Root mean squared error  6.388479024647287

# %%
from sklearn.ensemble import ExtraTreesRegressor
ETR=ExtraTreesRegressor()
ETR.fit(x_train,y_train)
predETR=ETR.predict(x_test)
pred_train=ETR.predict(x_train)
print("R2_score ", r2_score(y_test, predETR))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, predETR))
print("Mean squared error ", mean_squared_error(y_test,predETR))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, predETR)))
# Out:
# R2_score  0.8732085278696633
# R2_score on training data  99.57410888469308
# Mean Absolute Error  1.2411851637555438
# Mean squared error  5.839588885536182
# Root mean squared error  2.4165241330340943

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(LR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predLR)-score.mean())*100)
# Out:
# [0.80863318 0.71298947 0.82470691 0.77006184 0.75180248]
# 0.7736387768546357
# The difference between R2 score and CV score is  7.919071045200543

# %%
score = cross_val_score(RFR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predRFR)-score.mean())*100)
# Out:
# [0.84104315 0.72808694 0.84199765 0.81682514 0.79574551]
# 0.8047396787266315
# The difference between R2 score and CV score is  8.970771224129715

# %%
score = cross_val_score(knn,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predknn)-score.mean())*100)
# Out:
# [0.24985434 0.14902097 0.24771994 0.22402312 0.17854894]
# 0.20983346000516997
# The difference between R2 score and CV score is  3.263075370283866

# %%
score = cross_val_score(GBR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predGBR)-score.mean())*100)
# Out:
# [0.86611254 0.75350914 0.88219421 0.82730124 0.8132645 ]
# 0.8284763251814269
# The difference between R2 score and CV score is  8.121319296697482

# %%
score = cross_val_score(lasso,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predlasso)-score.mean())*100)
# Out:
# [0.63199503 0.60665446 0.63704085 0.62725889 0.54210015]
# 0.6090098769333266
# The difference between R2 score and CV score is  5.488695958001289

# %%
score = cross_val_score(ridge,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predridge)-score.mean())*100)
# Out:
# [0.80846594 0.71332212 0.82431887 0.77043619 0.75148294]
# 0.7736052111660845
# The difference between R2 score and CV score is  7.898894526468148

# %%
score = cross_val_score(DTR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predDTR)-score.mean())*100)
# Out:
# [0.71854962 0.5928505  0.58100104 0.68012796 0.54731866]
# 0.6239695565618126
# The difference between R2 score and CV score is  13.154163566074095

# %%
score = cross_val_score(svr,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predsvr)-score.mean())*100)
# Out:
# [ 0.00886985  0.08677646  0.10583429  0.06973751 -0.20241159]
# 0.013761302670074093
# The difference between R2 score and CV score is  10.009792902558605

# %%
score = cross_val_score(ETR,X,y)
print(score)
print(score.mean())
print('The difference between R2 score and CV score is ', (r2_score(y_test, predETR)-score.mean())*100)
# Out:
# [0.80674118 0.6891631  0.82295905 0.78626587 0.78384279]
# 0.777794398613693
# The difference between R2 score and CV score is  9.541412925597026

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_params = {'criterion':['friedman_mse','squared_error'],
              'min_samples_split': range(2,10,2),
               'min_samples_leaf': range(2,8,2),
               'max_depth': range(4,8),
               'learning_rate': np.arange(0.1,0.5),
               'random_state': range(1,60)}

# %%
grid = GridSearchCV(GradientBoostingRegressor(), grid_params, cv=5)
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error'],
#                          'learning_rate': array([0.1]),
#                          'max_depth': range(4, 8),
#                          'min_samples_leaf': range(2, 8, 2),
#                          'min_samples_split': range(2, 10, 2),
#                          'random_state': range(1, 60)})

# %%
grid.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'learning_rate': 0.1,
#  'max_depth': 4,
#  'min_samples_leaf': 2,
#  'min_samples_split': 8,
#  'random_state': 30}

# %%
Final_model = GradientBoostingRegressor(criterion= 'friedman_mse',learning_rate=0.1, max_depth = 4,
                                       min_samples_leaf = 2, min_samples_split = 8, random_state =30)
Final_model.fit(x_train, y_train)
pred=Final_model.predict(x_test)
pred_train=Final_model.predict(x_train)
print("R2_score ", r2_score(y_test, pred))
print("R2_score on training data ", r2_score(y_train,pred_train)*100)
print("Mean Absolute Error ",mean_absolute_error(y_test, pred))
print("Mean squared error ", mean_squared_error(y_test,pred))
print("Root mean squared error ", np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# R2_score  0.902125058576778
# R2_score on training data  88.76450965031768
# Mean Absolute Error  1.2404585121120577
# Mean squared error  4.507790709457347
# Root mean squared error  2.123155837299125

# %%
import pickle
filename = 'Health_insurance_analysis.pkl'
pickle.dump(Final_model, open(filename, 'wb'))

# %%
loaded_model= pickle.load(open('Health_insurance_analysis.pkl', 'rb'))
result = loaded_model.score(x_test, y_test)
print(result*100)
# Out:
# 90.21250585767781
